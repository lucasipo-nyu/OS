# %% [markdown]
# ### Luca Sipoteanu - Assignment 2
# **Inter-Process Communication using Unnamed Pipes**
#
# The program spawns 5 child processes, each handling a specific event type from the log file. The parent reads the events file, dispatches each line to the appropriate child via pipes, and then collects the processed results back.

# %%
# !cat a2.c

# %%
# !cat Makefile

# %%
# !make clean && make && ./a2 events_log.txt
